# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # 1 A simple plot

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 5, 10, 15, 20, 25, 30]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_2, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #for grids
plt.legend(loc='upper left') #for legends, done at the end, everything can be customised

# %%
#Things that can be abbreviated
#colour: c
#linestyle: ls
#linewidth: lw
# data
x = [0, 5, 10, 15, 20, 25, 30]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# plots
plt.plot(x, y_2, label='Y values',
         c='b', ls='-', lw = 3) #or even c='b--'for dotted blue line
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #for grids
plt.legend(loc='upper left')
#plt.show() -- impt to show the graph in python terminal

# %%
#2 lines in 1 graph
plt.plot(x, y_1, label = 'a')
plt.plot(x, y_2, label = 'b')
plt.legend()

# %%
plt.plot(x,y_1,
        c = 'red',
        label = 'y-values',
        ls = '-')
plt.legend()

# %% [markdown]
# ## 1.2 Adding another plot

# %%
# Not straight lines
x = [0, 2, 4, 6, 8, 10]
y_1 = [1, 2, 4, 9, 17, 22]
y_2 = [0, 3, 5, 8, 12, 15]

#plots
plt.plot(x, y_1, label='Y1 values', color='orange', linestyle='dashed') #might need to be careful abt colour chosen eg. colour blindness; can ref 'colour brewer' for colours that can be used / 'Paul Tol'; some colours grab ppl's attention more sometimes, but colours do not always need to be used, can even differentiate based on lines style
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
x = [0, 5, 10, 15, 20, 25, 30]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green', alpha = 0.5)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
# Some data for plotting
x = [0, 5, 10, 15, 20, 25, 30]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = [0, 2, 4, 6, 8, 10, 12], 0.75 #something weird

# Lets start plotting
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green', alpha = .5)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #reduce the boldness of the grid lines
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

# %%
#able to do numpy arrays, able ot do mathematics
# Some data for plotting
x = [0, 5, 10, 15, 20, 25, 30]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1**3, color='red', linestyle='dashed', label='Y values') #able to do math stuff to transform the graph
plt.plot(np_x, np_y_2+1385, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 5, 10, 15, 20, 25, 30])

x2 = x**2              #graph of x**2
sin_x = np.sin(x)      #graph of sin, will not work if you use some other package instead of numpy

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', ) #can you restrict the maximum value of y-axis to eg. 100? plt.ylim([-100, 100])
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ### Using a different axis

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='upper right')    #needed before twinx()  for this graph to have a legend                           

plt.twinx() #new y-axis; 2 graphs in 1-graph, just so happens they share the same x-axis, can actually use twiny for the same y-axis                                         
                                                           
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right') #loc indicates location of where the legends should go

# %%
x = np.arange(0, 12, .5) #make graphs nicer OR ref↓
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='upper right')                            

plt.twinx()                                       
                                                           
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')

# %%
x = np.linspace(0,3*np.pi,100)  #キレイ〜
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='upper right')                            

plt.twinx()                                       
                                                           
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')

# %%
x = np.linspace(0,6,100) 
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc=(.1, .25))       #ways to change legends; anything more than 1 --> out of graph frame                

plt.twinx()                                       
                                                           
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc=(.1, .35)) #such that these are closer to each other

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0,6,100) 
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc=(.1, .25))

plt.twinx()                                       
                                                           
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc=(.1, .35))

plt.savefig('plot.png', dpi = 500, transparent = True ) #saving graph #dpi: dense & resolution - have some restrictions sometimes; extensions can be changed to get diff files
#bitmat (eg. png: becomes very pixalated when zoomed) vs vector (eg. pdf: clear no matter how much you zoom)
#transparent = True: background is transparent (but only works for png)

# %% [markdown]
# OR
# ![](plot.png)

# %%
filename = 'spectrum-01.txt'
#np.loadtxt(filename) --> error will occur with this only since there are strings in the beginning followed by values. hence, should skip the first 2 lines
data = np.loadtxt(filename, skiprows=2) #skip first 2 rows: 2 columns, many rows
x = data[:,0] #all rows - :, first column
y = data[:,1] #all rows - :, second column
plt.plot(x,y) #when have data, always plot to see what it looks like

# %% [markdown]
# # 4 A real example: Global Warming

# %%
#skip the rows that are strings

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
plt.style.use('default')
filename = 'Complete_TAVG_daily.txt'
data = np.loadtxt(filename, skiprows = 23)
year = data[:,1]
anomaly = data[:,-1]
plt.plot(year, anomaly)
plt.grid(alpha = 0.5)
plt.hlines(0,year[0],year[-1],color = 'red', ls = 'dashed') #draws that straight line at 0
plt.savefig('temperature.png')

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('ggplot') #using ggplot style

filename = 'Complete_TAVG_daily.txt'
data = np.loadtxt(filename, skiprows = 23)
year = data[:,1]
anomaly = data[:,-1]
plt.plot(year, anomaly)
plt.grid(alpha = 0.5)
plt.hlines(0,year[0],year[-1],color = 'blue', ls = 'dashed')
plt.savefig('temperature1.png')

# %%
plt.style.use('fivethirtyeight') #using5308 style, once enabled, all other graphs will be in this style

filename = 'Complete_TAVG_daily.txt'
data = np.loadtxt(filename, skiprows = 23)
year = data[:,1]
anomaly = data[:,-1]
plt.plot(year, anomaly)
plt.grid(alpha = 0.5)
plt.hlines(0,year[0],year[-1],color = 'blue', ls = 'dashed')
plt.savefig('temperature2.png')

# %% [markdown]
# Refer to [Matplotlib Style Gallery](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html) for more different styles

# %%
#Cute
#plt.xkcd() #comic strip-ish
filename = 'Complete_TAVG_daily.txt'
data = np.loadtxt(filename, skiprows = 23)
year = data[:,1]
anomaly = data[:,-1]
plt.plot(year, anomaly)
plt.grid(alpha = 0.5)
plt.hlines(0,year[0],year[-1],color = 'blue', ls = 'dashed')
plt.savefig('temperature2.png')

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
