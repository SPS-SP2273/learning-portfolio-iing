# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need)</span></div>

# %%
# !pwd #mac pathway finder
# Out:
# /Users/guestuser/Desktop/Y1S2 subjects/SP2273/GitHub/learning-portfolio-iing/6 files, folders & os

# %% [markdown]
# # 1 Important concepts

# %%
#work on all sorts of operating systems without being subjected to the whims of that system

# %% [markdown]
# ## 1.1 Path

# %%
#absolute path: finding the exact path to the file that you want in your com
#relative path: relative to current location (easier, but might screw things up if your current location change, since it means that your rel. position will also change)

# %%
#learning portfolio path
"/Users/guestuser/Desktop/Y1S2 subjects/SP2273/GitHub/learning-portfolio-iing/6 files, folders & os"
#note: ~ can replace '/Users/guestuser'
# Out:
# '/Users/guestuser/Desktop/Y1S2 subjects/SP2273/GitHub/learning-portfolio-iing/6 files, folders & os'

# %% [markdown]
# ## 1.2 More about relative paths

# %%
#current folder
.
#one folder above
..
#Eg.
../../../file_name #went 3 folders up
# Out:
#   Cell In[7], line 2
#     .
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.3 Path separator

# %%
#path separator for windows: \\
### 2 backslashes are needed just in case eg. print(my_path = \_\_\nata) --> will cause a gap between the preceeding and ata
#path separator for mac: /

# %% [markdown]
# ## 1.4 Text files vs. Binary files

# %%
#Text file: relationship goals (ie. understandable); can be opened on any software
#Binary file: what-- I can't read you at all red flags (ie. it's all gibberish); know format to extract

# %% [markdown]
# ## 1.5 Extensions

# %%
#able to hide extensions, extensions: can help the system to know what app to open the file / if 2 files have the same name, they can both exist in same folder due to diff ext
#eg. 
#for excel: ___.xlsx
#for pdf: ___.pdf
#for images: ___.tiff, ___.jpeg, ___.png etc...

# %% [markdown]
# # 2 Opening and closing files

# %% [markdown]
# ## 2.1 Reading data

# %%
with open('spectrum-01.txt', 'r') as file:    # 'r': read
    file_content = file.read()

print(file_content)
#no need to close
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
#OR
file = open('spectrum-01.txt', 'r') #stream
data = file.read()
print(data)
file.close() #remember to close file after opening; reco to use the above method
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %% [markdown]
# ## 2.2 Writing data

# %%
text = "俺は絶対に死ねない！一つでも命を奪ったら…お前はもう後戻り出来なくなる！\n 俺はそれを望んでいる"

# %%
print(text)
# Out:
# 俺は絶対に死ねない！一つでも命を奪ったら…お前はもう後戻り出来なくなる！
#  俺はそれを望んでいる

# %% [markdown]
# ### Writing to a file in one go

# %%
with open('名言.txt', 'w') as file:    #'w' means write, may overwrite stuff if not careful
    file.write(text)

# %%
#to append
with open('名言.txt', 'a') as file: 
    file.write(text)

# %% [markdown]
# ### Writing to a file, line by line

# %%
with open('名言.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %%
text.splitlines()
# Out:
# ['俺は絶対に死ねない！一つでも命を奪ったら…お前はもう後戻り出来なくなる！', ' 俺はそれを望んでいる']

# %% [markdown]
# # 3 Some useful packages

# %%
import os
import glob
import shutil
#importing once is enough

# %% [markdown]
# # 4 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path) #joins to give a path
# Out:
# ./all-data/sg-data/data-01.txt

# %%
path = os.path.join('.', 'subjects', 'NSW', 'reading_12c.pdf')
print(path)
# Out:
# ./subjects/NSW/reading_12c.pdf

# %% [markdown]
# # 5 Folders

# %% [markdown]
# ## 5.1 Creating folders

# %%
os.mkdir('tests')

# %%
os.mkdir('tests') #running again should give an error
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.mkdir('tests') #running again should give an error
#
# FileExistsError: [Errno 17] File exists: 'tests'

# %%
os.mkdir('Tests') #case sensitive, does not allow even if capital letter
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 os.mkdir('Tests') #case sensitive, does not allow even if capital letter
#
# FileExistsError: [Errno 17] File exists: 'Tests'

# %%
for types in ['t-test', 'z-test', 'F-test']:
    path = os.path.join('tests', types)
    print(f'Creating {path}')
    os.mkdir(path) #don't run this line until the whole code is correct
# Out:
# Creating tests/t-test
# Creating tests/z-test
# Creating tests/F-test

# %% [markdown]
# ## 5.2 Checking for existence

# %% [markdown]
# ### Using try-except

# %%
for types in ['t-test', 'z-test', 'F-test']:
    path = os.path.join('tests', types)
    try:
        os.mkdir(path)
        print(f"Created {path}")
    except FileExistsError:
        print(f'The {path} already exists')
# Out:
# The tests/t-test already exists
# The tests/z-test already exists
# Created tests/F-test

# %% [markdown]
# ### Using os.path.exists()

# %%
for types in ['t-test', 'z-test', 'F-test']:
    path = os.path.join('tests', types)
    if os.path.exists(path):
        print(f'The {path} already exists')
    else:
        os.mkdir(path)
        print(f'Created {path}')
# Out:
# Created tests/t-test
# The tests/z-test already exists
# The tests/F-test already exists

# %% [markdown]
# ## 5.3 Copying files

# %%
file_to_copy = 'sp2273_logo.png'
file_to_copy = 'spectrum-01.txt'
for types in ['t-test', 'z-test', 'F-test']:
    path_to_destination = os.path.join('tests', types) 
    file_path = os.path.join(path_to_destination, file_to_copy)
    shutil.copy(file_to_copy, path_to_destination)

# %%
file_to_copy = 'sp2273_logo.png'
file_to_copy = 'spectrum-01.txt'
for types in ['t-test', 'z-test', 'F-test']:
    path_to_destination = os.path.join('tests', types) 
    file_path = os.path.join(path_to_destination, file_to_copy)
    if os.path.exists(path_to_destination):
        print(f'{file_path} already exists')
    else:
        shutil.copy(file_to_copy, path_to_destination) #don't do this at the start, see whether things work before running this
        print(f'Copied file to {path_to_destination}')
# Out:
# tests/t-test/spectrum-01.txt already exists
# tests/z-test/spectrum-01.txt already exists
# tests/F-test/spectrum-01.txt already exists

# %%
file_to_copy = 'sp2273_logo.png'
file_to_copy = 'spectrum-01.txt'
for types in ['t-test', 'z-test', 'F-test']:
    path_to_imgs = os.path.join('tests', types, 'imagins') #create folder called 'imagins' 
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)
    
# Move logo file into a new folder 'imagins'
    current_path_of_logo = os.path.join('tests', types, file_to_copy)
    new_path_of_logo = os.path.join('tests', types, 'imagins', file_to_copy)

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo from {current_path_of_logo}to {new_path_of_logo}')
# Out:
# Moved logo from tests/t-test/spectrum-01.txtto tests/t-test/imagins/spectrum-01.txt
# Moved logo from tests/z-test/spectrum-01.txtto tests/z-test/imagins/spectrum-01.txt
# Moved logo from tests/F-test/spectrum-01.txtto tests/F-test/imagins/spectrum-01.txt

# %% [markdown]
# # 6 Listing and looking for files

# %% [markdown]
# ##### Example 1

# %%
glob.glob('*')
# Out:
# ['名言.txt',
#  'tests',
#  'files,_folders_&_os_(need).ipynb',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
#similar to 
# !pwd #?
# Out:
# /Users/guestuser/Desktop/Y1S2 subjects/SP2273/GitHub/learning-portfolio-iing/6 files, folders & os

# %% [markdown]
# ##### Example 2

# %%
glob.glob('*.txt')
# Out:
# ['名言.txt', 'spectrum-01.txt']

# %%
glob.glob('*p*') #anything that has p in the middle
# Out:
# ['files,_folders_&_os_(need).ipynb', 'sp2273_logo.png', 'spectrum-01.txt']

# %%
glob.glob('s*')
# Out:
# ['sp2273_logo.png', 'spectrum-01.txt']

# %% [markdown]
# ##### Example 3

# %%
glob.glob('te*/*/*')
# Out:
# ['tests/z-test/sp2273_logo.png',
#  'tests/z-test/imagins',
#  'tests/t-test/sp2273_logo.png',
#  'tests/t-test/imagins',
#  'tests/F-test/sp2273_logo.png',
#  'tests/F-test/imagins']

# %%
glob.glob('te*/*/i*')
# Out:
# ['tests/z-test/imagins', 'tests/t-test/imagins', 'tests/F-test/imagins']

# %% [markdown]
# ##### Example 4

# %%
glob.glob('te*/**', recursive = True)
# Out:
# ['tests/',
#  'tests/z-test',
#  'tests/z-test/sp2273_logo.png',
#  'tests/z-test/imagins',
#  'tests/z-test/imagins/sp2273_logo.png',
#  'tests/z-test/imagins/spectrum-01.txt',
#  'tests/t-test',
#  'tests/t-test/sp2273_logo.png',
#  'tests/t-test/imagins',
#  'tests/t-test/imagins/sp2273_logo.png',
#  'tests/t-test/imagins/spectrum-01.txt',
#  'tests/F-test',
#  'tests/F-test/sp2273_logo.png',
#  'tests/F-test/imagins',
#  'tests/F-test/imagins/sp2273_logo.png',
#  'tests/F-test/imagins/spectrum-01.txt']

# %%
glob.glob('te*/*', recursive = True)
#Why are these 2 different?
# Out:
# ['tests/z-test', 'tests/t-test', 'tests/F-test']

# %% [markdown]
# ##### Example 5

# %%
glob.glob('tests/**', recursive=True)
# Out:
# ['tests/',
#  'tests/z-test',
#  'tests/z-test/sp2273_logo.png',
#  'tests/z-test/imagins',
#  'tests/z-test/imagins/sp2273_logo.png',
#  'tests/z-test/imagins/spectrum-01.txt',
#  'tests/t-test',
#  'tests/t-test/sp2273_logo.png',
#  'tests/t-test/imagins',
#  'tests/t-test/imagins/sp2273_logo.png',
#  'tests/t-test/imagins/spectrum-01.txt',
#  'tests/F-test',
#  'tests/F-test/sp2273_logo.png',
#  'tests/F-test/imagins',
#  'tests/F-test/imagins/sp2273_logo.png',
#  'tests/F-test/imagins/spectrum-01.txt']

# %%
#### Additional stuff? combine with copying files
files_to_copy = glob.glob('*.docx')

# %%
for file_to_copy in files_to_copy:
    for types in ['t-test', 'z-test', 'F-test']:
        path_to_destination = os.path.join('tests', types)
        file_path = os.path.join(path_to_destination, file_to_copy)
        if os.path.exists(file_path):
            print(f'{file_path} already exists')
        else:
            #shutil.move(file_to_copy, path_to_destination)
            print(f'Copied {file_to_copy} to {path_to_destination}')
# Out:
# Copied just for laughs.docx to tests/t-test
# Copied just for laughs.docx to tests/z-test
# Copied just for laughs.docx to tests/F-test

# %%
#recursive shows you everything

# %% [markdown]
# # 7 Extracting file info

# %%
#using knowledge of subsetting
os.path.sep
# Out:
# '/'

# %%
path = 'tests/t-test/imagins/sp2273_logo.png'
path.split(os.path.sep)
# Out:
# ['tests', 't-test', 'imagins', 'sp2273_logo.png']

# %%
path = 'tests/t-test/imagins/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, 'has the extension', extension)
# Out:
# sp2273_logo.png has the extension png

# %%
#convenient function of splitting, so that no need to go through the above trouble
#split filename
os.path.split(path)
# Out:
# ('tests/t-test/imagins', 'sp2273_logo.png')

# %%
#split extension - tail becomes extension
os.path.splitext(path)
# Out:
# ('tests/t-test/imagins/sp2273_logo', '.png')

# %%
#name of directory (ie. the front part)
os.path.dirname(path)
# Out:
# 'tests/t-test/imagins'

# %% [markdown]
# # 8 Deleting stuff

# %%
#to delete files, don't play so much with this pls sad things
#os.remove('tests/t-test/imagins/sp2273_logo.png') #delete image only
#os.rmdir('tests/t-test') #delete whole folder
